# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
vi = pd.read_csv('/content/drive/MyDrive/NOTES/data/Vehicle_Insurance.csv')

# %%
vi
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
vi.drop_duplicates()
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
vi.shape
# Out:
# (381109, 12)

# %%
vi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
vi.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
vi.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
sns.heatmap(vi.isnull())
# Out:
# <Axes: >

# %%
#removing putliers

# %%
sns.boxplot(vi['Annual_Premium'])
# Out:
# <Axes: ylabel='Annual_Premium'>

# %%
# prompt: handel outliers of annual premium

# Calculate the IQR
Q1 = vi['Annual_Premium'].quantile(0.25)
Q3 = vi['Annual_Premium'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
vi = vi[(vi['Annual_Premium'] >= lower_bound) & (vi['Annual_Premium'] <= upper_bound)]

# %%
sns.boxplot(vi['Annual_Premium'])
# Out:
# <Axes: ylabel='Annual_Premium'>

# %%
# prompt: handel outliers of annual premium

# Calculate the IQR
Q1 = vi['Annual_Premium'].quantile(0.25)
Q3 = vi['Annual_Premium'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
vi = vi[(vi['Annual_Premium'] >= lower_bound) & (vi['Annual_Premium'] <= upper_bound)]

# %%
sns.boxplot(vi['Annual_Premium'])
# Out:
# <Axes: ylabel='Annual_Premium'>

# %%
# prompt: handel outliers of annual premium

# Calculate the IQR
Q1 = vi['Annual_Premium'].quantile(0.25)
Q3 = vi['Annual_Premium'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
vi = vi[(vi['Annual_Premium'] >= lower_bound) & (vi['Annual_Premium'] <= upper_bound)]

# %%
sns.boxplot(vi['Annual_Premium'])
# Out:
# <Axes: ylabel='Annual_Premium'>

# %%
# prompt: handel outliers of annual premium

# Calculate the IQR
Q1 = vi['Annual_Premium'].quantile(0.25)
Q3 = vi['Annual_Premium'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
vi = vi[(vi['Annual_Premium'] >= lower_bound) & (vi['Annual_Premium'] <= upper_bound)]

# %%
# prompt: handel outliers of annual premium

# Calculate the IQR
Q1 = vi['Annual_Premium'].quantile(0.25)
Q3 = vi['Annual_Premium'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
vi = vi[(vi['Annual_Premium'] >= lower_bound) & (vi['Annual_Premium'] <= upper_bound)]

# %%
sns.boxplot(vi['Annual_Premium'])
# Out:
# <Axes: ylabel='Annual_Premium'>

# %%
numeric_column=['Age','Region_Code','Annual_Premium','Policy_Sales_Channel','Vintage']
for column in numeric_column:
  plt.figure(figsize=(8,6))
  # Replace car_copy with the correct DataFrame name
  sns.histplot(data=vi, x=column, hue='Response', multiple="dodge",bins=20 ) # Changed 'insurance_claim' to 'Response'
  plt.show()

# %%
catagorical_column=['Gender','Driving_License','Previously_Insured','Vehicle_Age','Vehicle_Damage','Response']
for column in catagorical_column:
  plt.figure(figsize=(8,6))
  # Use 'Response' for the hue parameter
  sns.countplot(data=vi, x=column, hue='Response')
  plt.show()

# %%
x = vi.loc[:, ['Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage', 'Response']] # Removed the column 'insurance_claim'
x.corr()
# Out:
#                            Age  Driving_License  Region_Code  \
# Age                   1.000000        -0.078398     0.042689
# Driving_License      -0.078398         1.000000    -0.001004
# Region_Code           0.042689        -0.001004     1.000000
# Previously_Insured   -0.253943         0.014214    -0.023686
# Annual_Premium        0.047347        -0.009415    -0.001388
# Policy_Sales_Channel -0.576678         0.042931    -0.043143
# Vintage              -0.001507        -0.000672    -0.003021
# Response              0.110850         0.009459     0.009388
#
#                       Previously_Insured  Annual_Premium  \
# Age                            -0.253943        0.047347
# Driving_License                 0.014214       -0.009415
# Region_Code                    -0.023686       -0.001388
# Previously_Insured              1.000000        0.015737
# Annual_Premium                  0.015737        1.000000
# Policy_Sales_Channel            0.216759       -0.104841
# ...

# %%
numeric_df = vi.select_dtypes(include=['number'])

plt.figure(figsize=(10,6))
numeric_df.corr()['Response'].sort_values(ascending=False).plot(kind='bar', grid=True, color='orange')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(vi.select_dtypes(include=np.number).corr(), annot=True,cmap='flare')
# Out:
# <Axes: >
